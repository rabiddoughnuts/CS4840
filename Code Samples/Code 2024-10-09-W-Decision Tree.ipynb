# %% [markdown]
# # Build a decision tree for classification using Gini index

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

iris = load_iris()
X = iris.data[:, 2:] # petal length and width
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.40)

tree_clf = DecisionTreeClassifier(max_depth=2, random_state=42, criterion='gini')
tree_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=42)

# %%
from sklearn import tree

tree.plot_tree(tree_clf)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[0] <= 2.45\ngini = 0.666\nsamples = 90\nvalue = [31.0, 29.0, 30.0]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 31\nvalue = [31, 0, 0]'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'x[1] <= 1.65\ngini = 0.5\nsamples = 59\nvalue = [0, 29, 30]'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.121\nsamples = 31\nvalue = [0, 29, 2]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.0\nsamples = 28\nvalue = [0, 0, 28]')]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_pred = tree_clf.predict(X_test)

print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_test, y_pred)))

print('Micro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='micro')))
print('Micro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='micro')))
print('Micro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='micro')))

print('Macro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='macro')))
print('Macro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='macro')))
print('Macro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='macro')))
# Out:
# Accuracy: 0.93
#
# Micro Precision: 0.93
# Micro Recall: 0.93
# Micro F1-score: 0.93
#
# Macro Precision: 0.93
# Macro Recall: 0.93
# Macro F1-score: 0.93

# %% [markdown]
# # Build a decision tree for classification using entropy

# %%
tree_clf = DecisionTreeClassifier(max_depth=2, random_state=42, criterion='entropy')
tree_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=2, random_state=42)

# %%
tree.plot_tree(tree_clf)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[0] <= 2.45\nentropy = 1.584\nsamples = 90\nvalue = [31.0, 29.0, 30.0]'),
#  Text(0.2, 0.5, 'entropy = 0.0\nsamples = 31\nvalue = [31, 0, 0]'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'x[1] <= 1.65\nentropy = 1.0\nsamples = 59\nvalue = [0, 29, 30]'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'entropy = 0.345\nsamples = 31\nvalue = [0, 29, 2]'),
#  Text(0.8, 0.16666666666666666, 'entropy = 0.0\nsamples = 28\nvalue = [0, 0, 28]')]

# %%
y_pred = tree_clf.predict(X_test)

print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_test, y_pred)))

print('Micro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='micro')))
print('Micro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='micro')))
print('Micro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='micro')))

print('Macro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='macro')))
print('Macro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='macro')))
print('Macro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='macro')))
# Out:
# Accuracy: 0.93
#
# Micro Precision: 0.93
# Micro Recall: 0.93
# Micro F1-score: 0.93
#
# Macro Precision: 0.93
# Macro Recall: 0.93
# Macro F1-score: 0.93

# %% [markdown]
# # Estimating class probabilities

# %%
tree_clf.predict([[5, 1.5]])
# Out:
# array([1])

# %%
tree_clf.predict_proba([[5, 1.5]])
# Out:
# array([[0.        , 0.93548387, 0.06451613]])

# %% [markdown]
# # Decision tree for regression

# %%
import numpy as np
import matplotlib.pyplot as plt

# Quadratic training set + noise
np.random.seed(42)
m = 200
X = np.random.rand(m, 1)
y = 10 * (X - 0.5) ** 2
y = y + np.random.randn(m, 1) / 3


plt.plot(X, y, 'b.')
plt.xlabel("X", fontsize=18)
plt.ylabel("y", fontsize=14, rotation=0)
plt.axis([0, 1, -2, 4])
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor(max_depth=3, random_state=42)
tree_reg.fit(X, y)
# Out:
# DecisionTreeRegressor(max_depth=3, random_state=42)

# %%
tree.plot_tree(tree_reg)
# Out:
# [Text(0.5, 0.875, 'x[0] <= 0.197\nsquared_error = 0.665\nsamples = 200\nvalue = 0.89'),
#  Text(0.25, 0.625, 'x[0] <= 0.092\nsquared_error = 0.277\nsamples = 44\nvalue = 1.757'),
#  Text(0.375, 0.75, 'True  '),
#  Text(0.125, 0.375, 'x[0] <= 0.046\nsquared_error = 0.157\nsamples = 20\nvalue = 2.162'),
#  Text(0.0625, 0.125, 'squared_error = 0.122\nsamples = 10\nvalue = 2.408'),
#  Text(0.1875, 0.125, 'squared_error = 0.072\nsamples = 10\nvalue = 1.916'),
#  Text(0.375, 0.375, 'x[0] <= 0.191\nsquared_error = 0.127\nsamples = 24\nvalue = 1.419'),
#  Text(0.3125, 0.125, 'squared_error = 0.104\nsamples = 23\nvalue = 1.385'),
#  Text(0.4375, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 2.209'),
#  Text(0.75, 0.625, 'x[0] <= 0.772\nsquared_error = 0.502\nsamples = 156\nvalue = 0.646'),
#  Text(0.625, 0.75, '  False'),
#  Text(0.625, 0.375, 'x[0] <= 0.287\nsquared_error = 0.13\nsamples = 110\nvalue = 0.269'),
#  Text(0.5625, 0.125, 'squared_error = 0.059\nsamples = 19\nvalue = 0.564'),
#  Text(0.6875, 0.125, 'squared_error = 0.123\nsamples = 91\nvalue = 0.207'),
#  Text(0.875, 0.375, 'x[0] <= 0.904\nsquared_error = 0.242\nsamples = 46\nvalue = 1.547'),
#  Text(0.8125, 0.125, 'squared_error = 0.088\nsamples = 28\nvalue = 1.232'),
#  Text(0.9375, 0.125, 'squared_error = 0.088\nsamples = 18\nvalue = 2.036')]

# %%
plt.plot(X, y, "b.")
plt.plot(X, tree_reg.predict(X), "r.")
plt.xlabel("X", fontsize=18)
plt.ylabel("y", fontsize=14, rotation=0)
plt.axis([0, 1, -2, 4])
plt.show()
